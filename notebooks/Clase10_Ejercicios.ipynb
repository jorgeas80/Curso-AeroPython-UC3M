# %% [markdown]
# <img src="../static/logopython.png" alt="Logo Python" style="width: 300px; display: inline"/>
# <img src="../static/deimoslogo.png" alt="Logo Deimos" style="width: 300px; display: inline"/>

# %% [markdown]
# # Clase 10: Ejercicios prácticos
#
# En esta clase vamos a afianzar los conocimientos de Python que acabamos de adquirir haciendo algunos ejercicios sobre matplotlib

# %%
# Importamos numpy para los ejercicios
import numpy as np

# %%
# Permitimos gráficas en el notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ejercicio 1
#
# Representa gráficamente esta función
#
# ```python
# def F(x):
#     return np.log(x) - np.sin(x)```
#
# Puedes usar esta escala para el eje X
#
# ```python
# x = np.linspace(0, 10, num=100)```

# %%
def F(x):
    return np.log(x) - np.sin(x)


x = np.linspace(0, 10, num=100)
plt.plot(x, F(x), 'k', lw=2, label="$F(x)$")
plt.plot(x, np.log(x), label="$\log{x}$")
plt.plot(x, np.sin(x), label="$\sin{x}$")
plt.plot(x, np.zeros_like(x), 'k--')
plt.legend(loc=4)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:7: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ## Ejercicio 2
#
# Transforma el tablero de ajedrez del ejercicio 1 en un verdadero tablero de ajedrez
#
# ```python
# tablero = np.zeros((8, 8))
# tablero[1::2, ::2] = 1
# tablero[::2, 1::2] = 1
# tablero```
#
#
# __Pista__: Revisa el uso de la función [matshow](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.matshow)
#
# __Pista__: Fíjate en [este ejemplo de código](http://matplotlib.org/examples/pylab_examples/matshow.html), como se usa el parámetro posicional *cmap* para pasarle una escala de colores a matshow

# %%
tablero = np.zeros((8, 8))
tablero[1::2, ::2] = 1
tablero[::2, 1::2] = 1

plt.matshow(tablero, cmap=plt.cm.gray_r)

# %% [markdown]
# ## Ejercicio 3
#
#
# Crear una función que represente gráficamente esta expresión:
#
# $$\sin(2 \pi f_1 t) + \sin(2 \pi f_2 t)$$
#
# Siendo $f_1$ y $f_2$ argumentos de entrada (por defecto $10$ y $100$) y $t \in [0, 0.5]$. Además, debe mostrar:
#
# * leyenda,
# * título "Dos frecuencias",
# * eje x "Tiempo ($t$)"
#
# y usar algún estilo de los disponibles.
#
# __Pista__: Puedes usar linspace para generar la escala de tiempos:
#
# ```python
#     times = np.linspace(0, max_time, 1000)```

# %%
def frecuencias(f1, f2):
    max_time = 0.5
    times = np.linspace(0, max_time, 1000)
    signal = np.sin(2 * np.pi * f1 * times) + np.sin(2 * np.pi * f2 * times)
    with plt.style.context("ggplot"):
        plt.plot(signal, label="Señal")
        plt.xlabel("Tiempo ($t$)")
        plt.title("Dos frecuencias")
        plt.legend()
        
frecuencias(10, 100)

# %%
from IPython.html.widgets import interactive

interactive(frecuencias, f1=(10.0,200.0), f2=(10.0,200.0))

# %% [markdown]
# ##### <a rel="license" href="http://creativecommons.org/licenses/by/4.0/deed.es"><img alt="Licencia Creative Commons" style="border-width:0" src="http://i.creativecommons.org/l/by/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">Curso Python</span> por <span xmlns:cc="http://creativecommons.org/ns#" property="cc:attributionName">Jorge Arévalo</span> se distribuye bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/deed.es">Licencia Creative Commons Atribución 4.0 Internacional</a>.

# %% [markdown]
# ---
# _Las siguientes celdas contienen configuración del Notebook_
#
# _Para visualizar y utlizar los enlaces a Twitter el notebook debe ejecutarse como [seguro](http://ipython.org/ipython-doc/dev/notebook/security.html)_
#
#     File > Trusted Notebook

# %%
# Esta celda da el estilo al notebook
from IPython.core.display import HTML
css_file = '../static/styles/style.css'
HTML(open(css_file, "r").read())
# Out:
# /* This template is inspired in the one used by Lorena Barba
# in the numerical-mooc repository: https://github.com/numerical-mooc/numerical-mooc
# We thank her work and hope you also enjoy the look of the notobooks with this style */
#
# <link href='http://fonts.googleapis.com/css?family=Source+Sans+Pro|Josefin+Sans:400,700,400italic|Ubuntu+Condensed' rel='stylesheet' type='text/css'>
#
# El estilo se ha aplicado =)
#
# <style>
#
#
#
# #notebook_panel { /* main background */
#     background: #f7f7f7;
# }
#
# div.cell { /* set cell width */
#     width: 900px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 950px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.7em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# ...
