# %% [markdown]
# <img src="../static/logopython.png" alt="Logo Python" style="width: 300px; display: inline"/>
# <img src="../static/deimoslogo.png" alt="Logo Deimos" style="width: 300px; display: inline"/>

# %% [markdown]
# # Clase extra: Enlaces de interés
#
# Simplemente, unos enlaces que pueden resultar interesantes a perfiles cercanos al mundo de la ciencia y la ingeniería
#
# * [Scipy](http://docs.scipy.org/doc/): La librería Python para ciencia
#
# * [SymPy](http://www.sympy.org/en/index.html): La librería Python para cálculo simbólico
#
# * [Cuaderno de Jupyter de la revista Nature](http://www.nature.com/news/ipython-interactive-demo-7.21492): Trae ejemplos interactivos muy chulos de la potencia de matplotlib
#
# * [100 ejercicios de NumPy](http://www.labri.fr/perso/nrougier/teaching/numpy.100/index.html)
#
# * [Guía de NumPy para usuarios de Matlab](https://docs.scipy.org/doc/numpy-dev/user/numpy-for-matlab-users.html): Trae una equivalencia de funciones Matlab/Numpy
#
# * [Versión online de *Numerical Python*, de Robert Johansson](http://jrjohansson.github.io/numericalpython.html): Incluye enlaces a cuadernos de Jupyter de diversos temas reacionados con Python y las matemáticas
#
# * [Artículo de Pybonacci sobre creación de matrices con NumPy](https://pybonacci.wordpress.com/2012/06/11/como-crear-matrices-en-python-con-numpy/)
#
# * [Artículo de Pybonacci sobre generación de números aleatorios con NumPy y Scipy](https://pybonacci.wordpress.com/2013/01/11/numeros-aleatorios-en-python-con-numpy-y-scipy/)
#
# * [Artículo de Pybonacci sobre la integración entre Fortran y Python usando F2PY](http://pybonacci.org/2013/02/22/integrar-fortran-con-python-usando-f2py/)
#
# * [Cuaderno de Jupyter de Robert Johansson sobre integración de Fortran y C con Python](http://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-6A-Fortran-and-C.ipynb)
#
# * [Cuaderno de Jupyter de Robert Johansson sobre herramientas para alto rendimiento en Python](http://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-6B-HPC.ipynb)
#
# * [Ejemplo de optimización de algoritmo en Python usando Cython](https://github.com/yungyuc/cythonup/blob/master/module/intro_cython/2-Cython-Prime.ipynb): Más sobre Cython [aquí](https://en.wikipedia.org/wiki/Cython)
#
# * [Vídeo: Acelerando código Python con Numba](https://www.youtube.com/watch?v=cuiXCZz93tU&list=PLGBbVX_WvN7as_DnOGcpkSsUyXB1G_wqb&index=15): Más sobre Numba [aquí](https://en.wikipedia.org/wiki/Numba)
#
# * [Pequeño tutorial para empaquetar y distribuir aplicaciones escritas en Python](https://www.digitalocean.com/community/tutorials/how-to-package-and-distribute-python-applications): Orientado a aplicación web, pero los conceptos son aplicables a otro tipo de aplicaciones
#
# * [Pequeño ejemplo de llamada HTTP usando Python + la librería requests](https://gist.github.com/jorgeas80/02225c7632fad9abf64f49a3b1e7a7c4): Hemos visto un ejemplo asíncrono, pero éste es aun más sencillo. La documentación de requests está [aquí](http://docs.python-requests.org/en/master/)
#
# * [Guía para usar Excel con Python](https://automatetheboringstuff.com/chapter12/): Otro ejemplo para leer ficheros Excel

# %%
# Esta celda da el estilo al notebook
from IPython.core.display import HTML
css_file = '../static/styles/style.css'
HTML(open(css_file, "r").read())
# Out:
# /* This template is inspired in the one used by Lorena Barba
# in the numerical-mooc repository: https://github.com/numerical-mooc/numerical-mooc
# We thank her work and hope you also enjoy the look of the notobooks with this style */
#
# <link href='http://fonts.googleapis.com/css?family=Source+Sans+Pro|Josefin+Sans:400,700,400italic|Ubuntu+Condensed' rel='stylesheet' type='text/css'>
#
# El estilo se ha aplicado =)
#
# <style>
#
#
#
# #notebook_panel { /* main background */
#     background: #f7f7f7;
# }
#
# div.cell { /* set cell width */
#     width: 900px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 950px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.7em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# ...
